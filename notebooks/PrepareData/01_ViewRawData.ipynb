# %% [markdown]
# # 01 ViewRawData
#
# Notebook นี้ใช้สำหรับดูข้อมูลเบื้องต้น

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')

# %% [markdown]
# ## การโหลดข้อมูล
#
# โหลดไฟล์ข้อมูลจาก vwTimeStampDashbaord.csv

# %%
example_path = '../../data/raw/vwTimeStampDashboard_v3.csv'
df = pd.read_csv(example_path)
df.head()
# Out:
#   PlantName PickListType             PickDate  TruckSeqNo       CarType  \
# 0       SB1      Walk-in  2025-01-07 11:10:04         8.0  1.000000e+09
# 1       SB1      Walk-in  2025-02-03 15:17:08        26.0  1.000000e+09
# 2       SB1      Walk-in  2025-01-10 11:11:25         7.0  1.000000e+09
# 3       SB1      Walk-in  2025-05-09 16:02:58         7.0  1.000000e+09
# 4       SB1       SmartQ  2025-04-05 14:15:01        18.0  1.000000e+09
#
#      CarNo      PackListNo                                       CustomerName  \
# 0  89-0471  SB1PL250107022                  บ.จำหน่ายวัตถุก่อสร้าง จก. สาขา 3
# 1  บห 3671  SB1PL250203089  PO-LH-250102018 - ศุภาลัย ปาล์ม สปร ศุภาลัย ปา...
# 2  60-6947  SB1PL250110028  SCGR Nakhon Srithammarat Plant SCG Roofing Co....
# 3  71-9972  SB1PL250509064                        บริษัท วาลอฟท์ ดีไซน์ จำกัด
# 4  70-4568  SB1PL250405063                                   คุณแน็ท ท่ามะขาม
#
#              QueueTime PrepareForward  ... ACCESSORIESSapAmount  \
# 0  2025-01-07 11:10:09              N  ...                  0.0
# 1  2025-02-03 15:17:17              N  ...                  0.0
# 2  2025-01-09 16:54:47              N  ...                  0.0
# 3  2025-05-09 16:03:16              N  ...                 40.0
# 4  2024-12-11 14:39:32              Y  ...                 23.0
#
#    TruckOverTimeName  TruckOverTimeRemark            TileStart  \
# 0                NaN                  NaN  2025-01-07 11:13:27
# 1                NaN                  NaN  2025-02-03 15:22:35
# 2                NaN                  NaN  2025-01-10 11:18:11
# 3                NaN                  NaN  2025-05-09 17:38:03
# 4                NaN                  NaN  2025-04-05 14:44:55
#
#                TileEnd         FittingStart           FittingEnd  \
# 0  2025-01-07 11:14:50  2025-01-07 11:11:44  2025-01-07 11:12:30
# 1  2025-02-03 15:24:32                  NaN                  NaN
# 2  2025-01-10 11:18:11  2025-01-10 11:16:54  2025-01-10 11:18:11
# 3  2025-05-09 17:43:56  2025-05-09 16:07:58  2025-05-09 16:11:13
# 4  2025-04-05 15:03:58  2025-04-05 14:07:50  2025-04-05 14:13:43
#
#               AccStart               AccEnd Unnamed: 39
# 0                  NaN                  NaN         NaN
# 1                  NaN                  NaN         NaN
# 2                  NaN                  NaN         NaN
# 3  2025-05-09 16:11:29  2025-05-09 16:21:55         NaN
# 4  2025-04-05 14:14:39  2025-04-05 14:20:30         NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Data Type และขนาดข้อมูล
#
# ดูจำนวนแถว, จำนวนคอลัมน์, และชนิดข้อมูลของแต่ละคอลัมน์

# %%
print(f"rows: {df.shape[0]:,}")
print(f"columns: {df.shape[1]:,}")

dtype_summary = pd.DataFrame(
    {
        "column": df.columns,
        "dtype": df.dtypes.astype(str).values,
    }
)

dtype_summary.sort_values(["dtype", "column"]).reset_index(drop=True)
# Out:
# rows: 32,505
# columns: 40
#                       column    dtype
# 0       ACCESSORIESSapAmount  float64
# 1       CPACFittingSapAmount  float64
# 2                    CarType  float64
# 3       DURAFittingSapAmount  float64
# 4   NEUSTILEFittingSapAmount  float64
# 5      NEUSTILETileSapAmount  float64
# 6   PRESTIGEFittingSapAmount  float64
# 7      PRESTIGETileSapAmount  float64
# 8           TruckReceiveHour  float64
# 9         TruckReceiveMinute  float64
# 10                TruckSeqNo  float64
# 11               Unnamed: 39  float64
# 12                    AccEnd      str
# 13                  AccStart      str
# 14         CPACTileSapAmount      str
# 15                CarConfirm      str
# 16                     CarNo      str
# 17                CreateDate      str
# 18              CustomerName      str
# 19           FirstPostPallet      str
# 20                FittingEnd      str
# 21              FittingStart      str
# 22            LastPostPallet      str
# 23        OperatorCarConfirm      str
# 24                PackListNo      str
# 25            PackListStatus      str
# 26                  PickDate      str
# 27              PickListType      str
# 28               PickingTime      str
# 29                 PlantName      str
# 30          PostLocationName      str
# 31               PostingTime      str
# 32            PrepareForward      str
# 33                 QueueTime      str
# 34                   TileEnd      str
# 35                 TileStart      str
# 36         TruckOverTimeName      str
# 37       TruckOverTimeRemark      str
# 38          TruckReceiveDate      str
# 39               TruckStatus      str

# %% [markdown]
# ## Missing Values
#
# สรุปคอลัมน์ที่มีค่าว่าง โดยนับรวมค่า `NULL` เป็น missing

# %%
null_like_tokens = ["NULL", "", "nan", "NaN", "None"]
df_profile = df.replace(null_like_tokens, np.nan)

missing_summary = pd.DataFrame(
    {
        "column": df_profile.columns,
        "missing_count": df_profile.isna().sum().values,
        "missing_pct": (df_profile.isna().mean() * 100).round(2).values,
    }
)

missing_summary = missing_summary.loc[missing_summary["missing_count"] > 0].copy()
missing_summary = missing_summary.sort_values("missing_count", ascending=False).reset_index(drop=True)
missing_summary
# Out:
#                       column  missing_count  missing_pct
# 0                Unnamed: 39          32504       100.00
# 1        TruckOverTimeRemark          32382        99.62
# 2          TruckOverTimeName          32352        99.53
# 3                     AccEnd          16956        52.16
# 4                   AccStart          16951        52.15
# 5               FittingStart          14237        43.80
# 6                 FittingEnd          14236        43.80
# 7                  TileStart           5516        16.97
# 8                    TileEnd           5511        16.95
# 9            FirstPostPallet            328         1.01
# 10            LastPostPallet            328         1.01
# 11                 QueueTime            120         0.37
# 12               PostingTime             10         0.03
# 13                PackListNo              5         0.02
# 14              CustomerName              1         0.00
# 15        TruckReceiveMinute              1         0.00
# 16          TruckReceiveDate              1         0.00
# 17            PrepareForward              1         0.00
# 18         CPACTileSapAmount              1         0.00
# 19          PostLocationName              1         0.00
# 20            PackListStatus              1         0.00
# 21               TruckStatus              1         0.00
# 22                CarConfirm              1         0.00
# 23                CreateDate              1         0.00
# 24               PickingTime              1         0.00
# 25        OperatorCarConfirm              1         0.00
# 26          TruckReceiveHour              1         0.00
# 27      ACCESSORIESSapAmount              1         0.00
# 28  NEUSTILEFittingSapAmount              1         0.00
# 29      DURAFittingSapAmount              1         0.00
# 30     NEUSTILETileSapAmount              1         0.00
# 31      CPACFittingSapAmount              1         0.00
# 32     PRESTIGETileSapAmount              1         0.00
# 33  PRESTIGEFittingSapAmount              1         0.00
